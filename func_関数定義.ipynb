# %%
# 関数のスプリクト内容が変更されても反映されるようにするおまじない
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from functions_py import util

# %%
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline

im = cv2.imread('diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Mild/0024cdab0c1e.png')
im = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
plt.imshow(im)

# %%
crop_im = util.crop_img(im)
plt.imshow(crop_im)
